# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Data

# %%
from utils.paths import DATA_DIR

# %%
df = pd.read_json(DATA_DIR / "pcos_data_cleaned.jsonl", lines=True)

# %%
df = df.copy()
df.head()
# Out:
#    pcos   Age (yrs)  weight_kg  Height(Cm)   Pulse rate(bpm)   rr_breaths  \
# 0     0          28       44.6        152.0                78          22
# 1     0          36       65.0        161.5                74          20
# 2     1          33       68.8        165.0                72          18
# 3     0          37       65.0        148.0                72          20
# 4     0          25       52.0        161.0                72          18
#
#       hb  cycle  marriage_yrs  pregnant  ...  follicle_size_r  endometrium  \
# 0  10.48      0           7.0         0  ...             18.0          8.5
# 1  11.70      0          11.0         1  ...             14.0          3.7
# 2  11.80      0          10.0         1  ...             20.0         10.0
# 3  12.00      0           4.0         0  ...             14.0          7.5
# 4  10.00      0           1.0         1  ...             14.0          7.0
#
#    blood_11  blood_12  blood_13  blood_14  blood_15  blood_16  blood_17  \
# 0     False     False     False     False      True     False     False
# 1     False     False     False     False      True     False     False
# 2      True     False     False     False     False     False     False
# 3     False     False      True     False     False     False     False
# 4      True     False     False     False     False     False     False
#
#    blood_18
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#
# [5 rows x 44 columns]

# %%
columns_to_drop = ["blood_18", "blood_17", "blood_16", "blood_15", "blood_14", "blood_13", "blood_12", "blood_11"]
df = df.drop(columns_to_drop, axis=1)

# %%
df.head()
# Out:
#    pcos   Age (yrs)  weight_kg  Height(Cm)   Pulse rate(bpm)   rr_breaths  \
# 0     0          28       44.6        152.0                78          22
# 1     0          36       65.0        161.5                74          20
# 2     1          33       68.8        165.0                72          18
# 3     0          37       65.0        148.0                72          20
# 4     0          25       52.0        161.0                72          18
#
#       hb  cycle  marriage_yrs  pregnant  ...  pimples  fast_food  exercise  \
# 0  10.48      0           7.0         0  ...        0          1         0
# 1  11.70      0          11.0         1  ...        0          0         0
# 2  11.80      0          10.0         1  ...        1          1         0
# 3  12.00      0           4.0         0  ...        0          0         0
# 4  10.00      0           1.0         1  ...        0          0         0
#
#    bp_systolic  bp_diastolic  follicle_l  follicle_r  follicle_size_l  \
# 0          110            80           3           3             18.0
# 1          120            70           3           5             15.0
# 2          120            80          13          15             18.0
# 3          120            70           2           2             15.0
# 4          120            80           3           4             16.0
#
#    follicle_size_r  endometrium
# 0             18.0          8.5
# 1             14.0          3.7
# 2             20.0         10.0
# 3             14.0          7.5
# 4             14.0          7.0
#
# [5 rows x 36 columns]

# %%
columns = df.columns
print(columns.tolist())
# Out:
# ['pcos', ' Age (yrs)', 'weight_kg', 'Height(Cm) ', 'Pulse rate(bpm) ', 'rr_breaths', 'hb', 'cycle', 'marriage_yrs', 'pregnant', 'abortions', '  I   beta-HCG(mIU/mL)', 'fsh', 'lh', 'hip', 'waist', 'tsh', 'amh', 'prl', 'vit_d3', 'prg', 'rbs', 'weight_gain', 'hair_growth', 'skin_darkening', 'hair_loss', 'pimples', 'fast_food', 'exercise', 'bp_systolic', 'bp_diastolic', 'follicle_l', 'follicle_r', 'follicle_size_l', 'follicle_size_r', 'endometrium']

# %%
for col in df.columns:
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
labels = df["pcos"]
df = df.drop(["pcos"])
